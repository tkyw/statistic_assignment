# %%
file_location = r"C:\Users\USER\Downloads\Survey form (1).csv"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
# %matplotlib inline
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv(file_location)
df
# Out:
#                         Timestamp               Username  \
# 0    2022/05/12 12:36:13 AM GMT+8   ngshitao93@gmail.com
# 1    2022/05/12 12:37:09 AM GMT+8    shangyet7@gmail.com
# 2    2022/05/12 12:41:08 AM GMT+8  jonaslol158@gmail.com
# 3    2022/05/12 12:41:17 AM GMT+8  chai.ruyuen@gmail.com
# 4    2022/05/12 12:57:34 AM GMT+8   tianzy0603@gmail.com
# ..                            ...                    ...
# 100  2022/06/08 12:44:24 AM GMT+8                    NaN
# 101  2022/06/08 12:45:04 AM GMT+8                    NaN
# 102  2022/06/08 12:46:01 AM GMT+8                    NaN
# 103  2022/06/08 12:48:46 AM GMT+8                    NaN
# 104  2022/06/08 12:49:37 AM GMT+8                    NaN
#
#     1. What is your gender? 2. What is your age?  \
# 0                      Male                18-22
# 1                      Male                18-22
# 2                      Male                18-22
# 3                    Female                18-22
# 4                      Male                18-22
# ..                      ...                  ...
# 100                  Female                23-30
# 101                    Male              Over 30
# 102                    Male              Over 30
# 103                    Male              Over 30
# 104                  Female                23-30
#
#     3. Which country you are currently working at?(skip this if you are unemployed)  \
# 0                                             Malaysia
# 1                                             Malaysia
# 2                                             Malaysia
# 3                                             Malaysia
# 4                                             Malaysia
# ..                                                 ...
# 100                                           Malaysia
# 101                                           Malaysia
# 102                                          Australia
# 103                                           Malaysia
# 104                                           Malaysia
#
#     4. Choose your income level (in terms of US dollar)  \
# 0                                    Full-time student
# 1                                    Full-time student
# 2                                    Full-time student
# 3                                           Below 2500
# 4                                    Full-time student
# ..                                                 ...
# 100                                         Below 2500
# 101                                         Below 2500
# 102                                      2,500 - 3,169
# 103                                         Below 2500
# 104                                         Below 2500
#
#     5. Choose your highest education level     6. Choose your academic status  \
# 0                               Foundation  Currently pursuing college degree
# 1                               Foundation  Currently pursuing college degree
# 2                           College Degree  Currently pursuing college degree
# 3                           College Degree  Currently pursuing college degree
# 4                           College Degree  Currently pursuing college degree
# ..                                     ...                                ...
# 100                 High Schooler or Below                       nongraduates
# 101                 High Schooler or Below                       nongraduates
# 102                 High Schooler or Below                       nongraduates
# 103                 High Schooler or Below                       nongraduates
# 104                 High Schooler or Below                       nongraduates
#
#     Please select only one option for each row. [7. I frequently feel nervous, on edge, or anxious.]  \
# 0                                              Neutral
# 1                                              Neutral
# 2                                              Neutral
# 3                                       Strongly Agree
# 4                                              Neutral
# ..                                                 ...
# 100                                              Agree
# 101                                              Agree
# 102                                            Neutral
# 103                                              Agree
# 104                                              Agree
#
#     Please select only one option for each row. [8. I always worry about something (e.g. : your life, your grades) and not being able to stop worrying.]  \
# 0                                                Agree
# 1                                                Agree
# 2                                                Agree
# 3                                       Strongly Agree
# 4                                              Neutral
# ..                                                 ...
# 100                                              Agree
# 101                                              Agree
# 102                                            Neutral
# 103                                              Agree
# 104                                              Agree
#
#      ...  \
# 0    ...
# 1    ...
# 2    ...
# 3    ...
# 4    ...
# ..   ...
# 100  ...
# 101  ...
# 102  ...
# 103  ...
# 104  ...
#
#     Please select only one option for each row. [23. I feel stress about my study]  \
# 0                                                Agree
# 1                                              Neutral
# 2                                                Agree
# 3                                       Strongly agree
# 4                                                Agree
# ..                                                 ...
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
# 103                                                NaN
# 104                                                NaN
#
#     Please select only one option for each row. [24. I think that most of the knowledges I'm learning now might not be useful in the future occupation.]  \
# 0                                              Neutral
# 1                                             Disagree
# 2                                                Agree
# 3                                             Disagree
# 4                                              Neutral
# ..                                                 ...
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
# 103                                                NaN
# 104                                                NaN
#
#     Please select only one option for each row. [25. I knew a lot of friends in college or university]  \
# 0                                              Neutral
# 1                                             Disagree
# 2                                                Agree
# 3                                             Disagree
# 4                                    Strongly disagree
# ..                                                 ...
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
# 103                                                NaN
# 104                                                NaN
#
#     Please select only one option for each row. [26. I believe that college degree study can equip me with a lot of knowledges that make me outstanding and competitive once I have graduated.]  \
# 0                                                Agree
# 1                                              Neutral
# 2                                                Agree
# 3                                                Agree
# 4                                                Agree
# ..                                                 ...
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
# 103                                                NaN
# 104                                                NaN
#
#            21. Why am I not pursuing a college degree?  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 100        Don't have an idea on which course to study
# 101      College Degree will not teach me what I want.
# 102  I was decided to drop out from college or univ...
# 103        Don't have an idea on which course to study
# 104        Don't have an idea on which course to study
#
#     Please select only one option for each row. [22. I am satisfy with my life even without a college degree.]  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 100                                            Neutral
# 101                                           Disagree
# 102                                     Strongly Agree
# 103                                           Disagree
# 104                                  Strongly disagree
#
#     Please select only one option for each row. [23. I feel less competitive to those who possess a college degree.]  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 100                                              Agree
# 101                                              Agree
# 102                                           Disagree
# 103                                              Agree
# 104                                              Agree
#
#      Please select only one option for each row. [24. I feel less confident. ]  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 100                                              Agree
# 101                                     Strongly Agree
# 102                                           Disagree
# 103                                              Agree
# 104                                              Agree
#
#      Please select only one option for each row. [25. I always worry my future because of not having a college degree.]  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 100                                              Agree
# 101                                              Agree
# 102                                  Strongly disagree
# 103                                              Agree
# 104                                     Strongly Agree
#
#     Please select only one option for each row. [26. I think that my life and achievements could be better off and happier if I possess a college degree.]
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 100                                              Agree
# 101                                              Agree
# 102                                            Neutral
# 103                                              Agree
# 104                                     Strongly Agree
#
# [105 rows x 45 columns]

# %% [markdown]
# # Linkage between Emotional Health and education level

# %%
cols = ["17. How do you rate your emotional (mental) health?", '4. Choose your income level (in terms of US dollar)', '5. Choose your highest education level', '18. How do you view your emotional (mental) health?']
l1 = df.loc[:, cols].rename(columns={
    cols[0]  : 'Emotional Health Score(1-10)',
    cols[1]  : 'Income Level',
    cols[2]  : 'Highest Education Level',
    cols[-1] : 'Emotional Stability'
})
l1
# Out:
#      Emotional Health Score(1-10)       Income Level Highest Education Level  \
# 0                               5  Full-time student              Foundation
# 1                               5  Full-time student              Foundation
# 2                               7  Full-time student          College Degree
# 3                               4         Below 2500          College Degree
# 4                               4  Full-time student          College Degree
# ..                            ...                ...                     ...
# 100                             2         Below 2500  High Schooler or Below
# 101                             4         Below 2500  High Schooler or Below
# 102                             8      2,500 - 3,169  High Schooler or Below
# 103                             3         Below 2500  High Schooler or Below
# 104                             4         Below 2500  High Schooler or Below
#
#                                    Emotional Stability
# 0    Most of the time I'm happy, but sometimes I wi...
# 1    Most of the time I'm happy, but sometimes I wi...
# 2    Most of the time I'm happy, but sometimes I wi...
# 3    Most of the time I'm happy, but sometimes I wi...
# 4    Most of the time I'm happy, but sometimes I wi...
# ..                                                 ...
# 100  I feel stressed out most of the time, whenever...
# 101  I feel stressed out most of the time, whenever...
# 102  I'm very satisfied with my life and feel happy...
# 103  I feel stressed out most of the time, whenever...
# 104  I feel stressed out most of the time, whenever...
#
# [105 rows x 4 columns]

# %%
em_stab = l1['Emotional Stability'].unique()
em_stab_scores = dict(zip(em_stab, [3, 2, 4, 1]))  # 1 = very unstable, 2 = unstable, 3 = stable, 4 = very stable
for em_stab_score in em_stab_scores:
    l1['Emotional Stability'] = l1['Emotional Stability'].apply(lambda x: em_stab_scores[em_stab_score] if x == em_stab_score else x)
l1
# Out:
#      Emotional Health Score(1-10)       Income Level Highest Education Level  \
# 0                               5  Full-time student              Foundation
# 1                               5  Full-time student              Foundation
# 2                               7  Full-time student          College Degree
# 3                               4         Below 2500          College Degree
# 4                               4  Full-time student          College Degree
# ..                            ...                ...                     ...
# 100                             2         Below 2500  High Schooler or Below
# 101                             4         Below 2500  High Schooler or Below
# 102                             8      2,500 - 3,169  High Schooler or Below
# 103                             3         Below 2500  High Schooler or Below
# 104                             4         Below 2500  High Schooler or Below
#
#      Emotional Stability
# 0                      3
# 1                      3
# 2                      3
# 3                      3
# 4                      3
# ..                   ...
# 100                    2
# 101                    2
# 102                    4
# 103                    2
# 104                    2
#
# [105 rows x 4 columns]

# %%
l1['Highest Education Level'].unique()
# Out:
# array(['Foundation', 'College Degree', 'Doctorate Degree',
#        'High Schooler or Below', 'Master Degree'], dtype=object)

# %%
l1['Income Level'].unique()
# Out:
# array(['Full-time student', 'Below 2500', 'Unemployed', '4,850 - 5,879',
#        '2,500 - 3,169', '5,880 - 7,099', '3,970 - 4,849',
#        '8,700 - 10,959', '7,110 - 8,699'], dtype=object)

# %%
l1.loc[(((l1['Highest Education Level'] == 'College Degree') & (l1['Income Level'] != 'Full-time student')) | (l1['Highest Education Level'] == 'Master Degree') | (l1['Highest Education Level'] == 'Doctorate Degree')), :]
# Out:
#     Emotional Health Score(1-10)    Income Level Highest Education Level  \
# 3                              4      Below 2500          College Degree
# 6                              4      Below 2500          College Degree
# 7                              7      Below 2500          College Degree
# 9                              3      Below 2500          College Degree
# 13                            10      Below 2500          College Degree
# 16                             7      Below 2500        Doctorate Degree
# 22                             5      Below 2500          College Degree
# 23                            10   4,850 - 5,879        Doctorate Degree
# 26                             8   2,500 - 3,169          College Degree
# 27                            10      Below 2500          College Degree
# 29                             4      Below 2500          College Degree
# 50                             9   3,970 - 4,849        Doctorate Degree
# 51                             7      Below 2500        Doctorate Degree
# 52                             8      Below 2500        Doctorate Degree
# 53                             5      Below 2500        Doctorate Degree
# 54                             9      Below 2500        Doctorate Degree
# 55                            10  8,700 - 10,959        Doctorate Degree
# 56                             7   2,500 - 3,169        Doctorate Degree
# 57                             9      Below 2500           Master Degree
# 58                             7      Below 2500        Doctorate Degree
# 59                             8      Below 2500          College Degree
# 65                            10   5,880 - 7,099          College Degree
# 66                             9   4,850 - 5,879          College Degree
# 67                             8   5,880 - 7,099          College Degree
# 68                             7   5,880 - 7,099          College Degree
# 69                             8   4,850 - 5,879          College Degree
# 70                             9   4,850 - 5,879          College Degree
# 71                             7   4,850 - 5,879          College Degree
# 72                             8   4,850 - 5,879          College Degree
# 73                             8   4,850 - 5,879          College Degree
# 74                             8   2,500 - 3,169          College Degree
# 75                             5      Below 2500          College Degree
# 76                             3      Below 2500          College Degree
# 77                             4      Below 2500          College Degree
# 78                             4      Below 2500          College Degree
# 79                             3      Below 2500          College Degree
# 80                             9   7,110 - 8,699          College Degree
# 81                             7   5,880 - 7,099          College Degree
# 82                             8   5,880 - 7,099          College Degree
# 83                             6   2,500 - 3,169          College Degree
# 84                             7   2,500 - 3,169        Doctorate Degree
# 87                             3      Below 2500          College Degree
# 91                             7   2,500 - 3,169          College Degree
# 97                             9   2,500 - 3,169          College Degree
#
#     Emotional Stability
# 3                     3
# 6                     2
# 7                     3
# 9                     2
# 13                    3
# 16                    3
# 22                    3
# 23                    4
# 26                    3
# 27                    4
# 29                    2
# 50                    4
# 51                    3
# 52                    3
# 53                    3
# 54                    3
# 55                    4
# 56                    3
# 57                    3
# 58                    3
# 59                    3
# 65                    3
# 66                    4
# 67                    3
# 68                    3
# 69                    3
# 70                    3
# 71                    3
# 72                    3
# 73                    3
# 74                    3
# 75                    2
# 76                    2
# 77                    2
# 78                    2
# 79                    2
# 80                    3
# 81                    3
# 82                    3
# 83                    3
# 84                    3
# 87                    2
# 91                    3
# 97                    3

# %%
em_health_score = ['1 - 3', '4 - 6', '>=7']

degree_holder_less_than_av_score = l1.query("(`Emotional Health Score(1-10)` <= 3) & (`Income Level` != 'Full-time student') & (`Highest Education Level` == 'College Degree' | `Highest Education Level` == 'Master Degree' | `Highest Education Level` == 'Doctorate Degree')").shape[0]
degree_holder_av_score = l1.query("(`Emotional Health Score(1-10)` >= 4 & `Emotional Health Score(1-10)` <= 6) & (`Income Level` != 'Full-time student') & (`Highest Education Level` == 'College Degree' | `Highest Education Level` == 'Master Degree' | `Highest Education Level` == 'Doctorate Degree')").shape[0]
degree_holder_above_av_score = l1.query("(`Emotional Health Score(1-10)` >= 7) & (`Income Level` != 'Full-time student') & (`Highest Education Level` == 'College Degree' | `Highest Education Level` == 'Master Degree' | `Highest Education Level` == 'Doctorate Degree')").shape[0]
degree_holders = [degree_holder_less_than_av_score, degree_holder_av_score, degree_holder_above_av_score]

non_degree_holder_less_than_av_score = l1.query("(`Emotional Health Score(1-10)` <= 3) & (`Highest Education Level` == 'Foundation' | `Highest Education Level` == 'High Schooler or Below' | (`Highest Education Level` == 'College Degree' & `Income Level` == 'Full-time student'))").shape[0]
non_degree_holder_av_score = l1.query("(`Emotional Health Score(1-10)` >= 4 & `Emotional Health Score(1-10)` <= 6) & (`Highest Education Level` == 'Foundation' | `Highest Education Level` == 'High Schooler or Below' | (`Highest Education Level` == 'College Degree' & `Income Level` == 'Full-time student'))").shape[0]
non_degree_holder_above_av_score = l1.query("(`Emotional Health Score(1-10)` >= 7) & (`Highest Education Level` == 'Foundation' | `Highest Education Level` == 'High Schooler or Below' | (`Highest Education Level` == 'College Degree' & `Income Level` == 'Full-time student'))").shape[0]
non_degree_holders = [non_degree_holder_less_than_av_score, non_degree_holder_av_score, non_degree_holder_above_av_score]

t_sample = np.array([np.array([(d, nd) for d, nd in zip(degree_holders, non_degree_holders)]).flatten()])

em_health_df = pd.DataFrame(t_sample, columns=pd.MultiIndex.from_product([['1 - 3', '4 - 6', '>=7'], ['Degree Holder', 'Nondegree Holder']]))
em_health_df = em_health_df.T
em_health_df.index.name = 'Emotional Health Score'
em_health_df.rename(columns={0 : 'Number Of People'}, inplace=True)

fig, ax = plt.subplots(figsize=(12,8))
degree_holders = [d / l1.shape[0]  * 100 for d in degree_holders]
non_degree_holders = [nd / l1.shape[0]  * 100 for nd in non_degree_holders]
ax.bar(em_health_score, degree_holders, color='#ff6361');
ax.bar(em_health_score, non_degree_holders, bottom=degree_holders, color='#003f5c');
plt.xlabel('Emotional Health Score', fontsize=16)
plt.ylabel('%, of People', fontsize=16)
plt.legend(['Degree Holders', 'Nondegree Holders'], fontsize=14)
plt.title('Emotional Health Score of Degree Holders and Nondegree Holders', fontsize=20);

for index in em_health_score:
    em_health_df.loc[index, 'Percentage Of People'] = em_health_df.loc[index, 'Number Of People'].values / df.shape[0]
em_health_df.to_clipboard(excel=True)
plt.savefig('Emotional Health Score of Degree Holders and Nondegree Holders.png', bbox_inches='tight');

# %% [markdown]
# ## Correlation between Degree Holder and Emotional Health

# %% [markdown]
# ### Degree Holders

# %%
degree_holders_df = l1.query("((`Highest Education Level` == 'College Degree' & `Income Level` != 'Full-time student') | `Highest Education Level` == 'Master Degree' | `Highest Education Level` == 'Doctorate Degree')")
degree_holders_df['Emotional Health Score(1-10)'].value_counts().sort_index()
# degree_holders_df
# Out:
# 3      4
# 4      5
# 5      3
# 6      1
# 7     10
# 8      9
# 9      7
# 10     5
# Name: Emotional Health Score(1-10), dtype: int64

# %% [markdown]
# ### Nondegree Holders

# %%
nondegree_holders_df = l1.query("((`Highest Education Level` == 'College Degree' & `Income Level` == 'Full-time student') | `Highest Education Level` == 'Foundation' | `Highest Education Level` == 'High Schooler or Below')")
nondegree_holders_df['Emotional Health Score(1-10)'].value_counts().sort_index().to_clipboard(excel=True, index=True, header=False)

# %% [markdown]
# # Descriptive Statistic

# %% [markdown]
# ## Degree Holders

# %%
cols = ['Please select only one option for each row. [25. I learned skills and knowledges in college.]', 'Please select only one option for each row. [26. I knew myriads of new friends in college or university.]', 'Please select only one option for each row. [29. Without a college degree, I am not able to reach my current achievement.]']
l2 = df.loc[:, cols].copy()
l2 = l2.dropna(axis=0)
items = {
    'Strongly disagree' : 1,
    'Disagree' : 2,
    'Neutral' : 3,
    'Agree' : 4,
    'Strongly agree' : 5
}

for item in items:
    l2 = l2.replace(item, items[item], regex=True)
mean_score = l2.std(axis=0)
mean_score
# l2['Please select only one option for each row. [29. Without a college degree, I am not able to reach my current achievement.]'].value_counts().sort_index()
# Out:
# Please select only one option for each row. [25. I learned skills and knowledges in college.]                                 0.745671
# Please select only one option for each row. [26. I knew myriads of new friends in college or university.]                     0.664328
# Please select only one option for each row. [29. Without a college degree, I am not able to reach my current achievement.]    1.047245
# dtype: float64
